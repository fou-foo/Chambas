# %%
import pandas as pd 
from plotnine import  *

# %%
data = pd.read_csv("reto_precios (4) (1).csv")
data.drop(["main_name", "subtitle", "link", "timestamp", "id", "description", "price_currency",  "price", "attributes", 
          "price_mod", "since", "since_value", "days_on_site", "since_period", "cellars", 
          "age_in_years"], inplace=True, axis= 1)

# %%
data
# Out:
#                                               location  \
# 0    Sinaloa 20 , Roma Sur, Roma Sur, Cuauhtémoc, D...
# 1     Tonala, Roma Norte, Cuauhtémoc, Distrito Federal
# 2    Tepeji 43, Roma Sur, Ciudad De México, Cdmx, M...
# 3      Linares, Roma Sur, Cuauhtémoc, Distrito Federal
# 4    Frontera, Roma Norte, Cuauhtémoc, Distrito Fed...
# ..                                                 ...
# 976  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 977  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 978  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 979  Querétaro, Roma Norte, Cuauhtémoc, Distrito Fe...
# 980  Bajío 315, Roma Sur, Cuauhtémoc, Distrito Federal
#
#                                                address  \
# 0                                Sinaloa 20 , Roma Sur
# 1                                               Tonala
# 2    Tepeji 43, Roma Sur, Ciudad De México, Cdmx, M...
# 3                                              Linares
# ...

# %%
data.columns
import folium
center = [data.lat.mean(), data.lon.mean()]
map = folium.Map(location = center, zoom_start = 5)
for i, j in data.iterrows():
    location = [j['lat'], j['lon']]
    folium.Marker(location, popup = f'Country:{j["location"]}').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data
# Out:
#                                               location  \
# 0    Sinaloa 20 , Roma Sur, Roma Sur, Cuauhtémoc, D...
# 1     Tonala, Roma Norte, Cuauhtémoc, Distrito Federal
# 2    Tepeji 43, Roma Sur, Ciudad De México, Cdmx, M...
# 3      Linares, Roma Sur, Cuauhtémoc, Distrito Federal
# 4    Frontera, Roma Norte, Cuauhtémoc, Distrito Fed...
# ..                                                 ...
# 976  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 977  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 978  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 979  Querétaro, Roma Norte, Cuauhtémoc, Distrito Fe...
# 980  Bajío 315, Roma Sur, Cuauhtémoc, Distrito Federal
#
#                                                address  \
# 0                                Sinaloa 20 , Roma Sur
# 1                                               Tonala
# 2    Tepeji 43, Roma Sur, Ciudad De México, Cdmx, M...
# 3                                              Linares
# ...

# %%
ggplot( data, aes(x='price_square_meter' )) + geom_density() + theme_minimal()
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot( data, aes(x="factor(bathrooms)", y='price_square_meter' )) + geom_boxplot() + theme_minimal()
# Out:
# <Figure Size: (640 x 480)>

# %%
data.columns
# Out:
# Index(['location', 'address', 'vendor', 'lat', 'lon', 'amenities', 'bathrooms',
#        'num_floors', 'monthly_fee', 'apartments_per_floor', 'disposition',
#        'parking_lots', 'floor_situated', 'orientation', 'num_bedrooms',
#        'department_type', 'm2', 'final_price', 'price_square_meter'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# location                  0
# address                 279
# vendor                    0
# lat                       0
# lon                       0
# amenities               477
# bathrooms                 0
# num_floors              897
# monthly_fee             853
# apartments_per_floor    966
# disposition             961
# parking_lots              0
# floor_situated          957
# orientation             973
# num_bedrooms              0
# department_type         942
# m2                        0
# final_price               0
# price_square_meter        0
# dtype: int64

# %%
data.drop( ["address", "amenities", "num_floors", "monthly_fee", "apartments_per_floor", "disposition", "floor_situated", "orientation", "department_type" ], 
          axis= 1, inplace=True)

# %%
import googlemaps
import time
gmaps = googlemaps.Client(key='AIzaSyBuujzvq1s5QHI5wXBtyMtBEtzwQrYgEU0')

data['ZIP']="-00000"
#AIzaSyBuujzvq1s5QHI5wXBtyMtBEtzwQrYgEU0

# %%
_ = 0
gmaps.reverse_geocode(( data.lat[_] , data.lon[_] ) )[1]["address_components"][-3]
# Out:
# {'long_name': 'Ciudad de México',
#  'short_name': 'CDMX',
#  'types': ['administrative_area_level_1', 'political']}

# %%
# Look up an address with reverse geocoding

for _ in data.index:
    data.loc[_, 'Calle'] = gmaps.reverse_geocode(( data.lat[_] , data.lon[_] ))[0]["address_components"][1]['long_name']
    data.loc[_, 'Ciudad'] = gmaps.reverse_geocode(( data.lat[_] , data.lon[_] ))[0]["address_components"][-3]["long_name"]
    data.loc[_, 'ZIP'] = gmaps.reverse_geocode(( data.lat[_] , data.lon[_] ))[0]["address_components"][-1]["long_name"]
    time.sleep(.001)

# %%
data
# Out:
#                                               location  \
# 0    Sinaloa 20 , Roma Sur, Roma Sur, Cuauhtémoc, D...
# 1     Tonala, Roma Norte, Cuauhtémoc, Distrito Federal
# 2    Tepeji 43, Roma Sur, Ciudad De México, Cdmx, M...
# 3      Linares, Roma Sur, Cuauhtémoc, Distrito Federal
# 4    Frontera, Roma Norte, Cuauhtémoc, Distrito Fed...
# ..                                                 ...
# 976  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 977  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 978  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 979  Querétaro, Roma Norte, Cuauhtémoc, Distrito Fe...
# 980  Bajío 315, Roma Sur, Cuauhtémoc, Distrito Federal
#
#                        vendor        lat        lon  bathrooms  parking_lots  \
# 0                   Investemx  19.421317 -99.164182        2.0             2
# 1                     Avitana  19.421029 -99.163541        1.0             1
# ...

# %%
data.isna().sum()
# Out:
# location              0
# vendor                0
# lat                   0
# lon                   0
# bathrooms             0
# parking_lots          0
# num_bedrooms          0
# m2                    0
# final_price           0
# price_square_meter    0
# ZIP                   0
# Calle                 0
# Ciudad                0
# dtype: int64

# %%
data.Ciudad.value_counts()
# Out:
# Ciudad
# Ciudad de México    944
# Nuevo León           36
# Baja California       1
# Name: count, dtype: int64

# %%
data.to_csv("data_reversed.csv", index=False)

# %%
import pandas as pd 
data = pd.read_csv("data_reversed.csv")
data.ZIP = data.ZIP.astype(str)

# %%
data_mex = data[data.Ciudad=='Ciudad de México'].copy()

# %%
data_mex['y']=data_mex.final_price/data_mex.m2
data_mex
# Out:
#                                               location  \
# 0    Sinaloa 20 , Roma Sur, Roma Sur, Cuauhtémoc, D...
# 1     Tonala, Roma Norte, Cuauhtémoc, Distrito Federal
# 2    Tepeji 43, Roma Sur, Ciudad De México, Cdmx, M...
# 3      Linares, Roma Sur, Cuauhtémoc, Distrito Federal
# 4    Frontera, Roma Norte, Cuauhtémoc, Distrito Fed...
# ..                                                 ...
# 976  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 977  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 978  Monterrey, Roma Sur, Cuauhtémoc, Distrito Federal
# 979  Querétaro, Roma Norte, Cuauhtémoc, Distrito Fe...
# 980  Bajío 315, Roma Sur, Cuauhtémoc, Distrito Federal
#
#                        vendor        lat        lon  bathrooms  parking_lots  \
# 0                   Investemx  19.421317 -99.164182        2.0             2
# 1                     Avitana  19.421029 -99.163541        1.0             1
# ...

# %%
import statsmodels.api as sm
import numpy as np
Y = data['price_square_meter']
X = data[["bathrooms", "parking_lots", "num_bedrooms" , "m2", "final_price", "ZIP" ] ]

X = sm.add_constant(X)

# %%
model = sm.WLS.from_formula(formula = "price_square_meter ~ bathrooms + parking_lots + num_bedrooms + m2   + Calle   ", data = data) 
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ...
# Dep. Variable:     price_square_meter   R-squared:                       0.365
# Model:                            WLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     3.900
# Date:                Sat, 19 Aug 2023   Prob (F-statistic):           1.59e-32
# Time:                        22:22:45   Log-Likelihood:                -10850.
# No. Observations:                 981   AIC:                         2.195e+04
# Df Residuals:                     854   BIC:                         2.258e+04
# Df Model:                         126
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %%
data_mex = data_mex.sort_values( by = ['price_square_meter' ] , ascending=False) 
data_mex[['price_square_meter', 'Calle']]
# Out:
#      price_square_meter                Calle
# 162       146524.373626               Tonalá
# 292       145000.000000               Toluca
# 627       123939.489796               Colima
# 696       123388.888889     Calle de Durango
# 685       122805.555556     Calle de Durango
# ..                  ...                  ...
# 475         6133.333333  Eje Vial 3 Poniente
# 469         5351.968153           Hermosillo
# 952         4712.041885             Acapulco
# 956         2932.076453           Valladolid
# 541          582.246879         Quintana Roo
#
# [944 rows x 2 columns]

# %%
data_mex.drop(['location', 'vendor', 'lat', 'lon', 'y' ], inplace= True , axis= 1) 
data_mex
# Out:
#      bathrooms  parking_lots  num_bedrooms      m2  final_price  \
# 162        2.0             2           2.0    91.0   13333718.0
# 292        2.0             2           3.0   154.0   22330000.0
# 627        2.0             2           2.0    98.0   12146070.0
# 696        1.0             1           1.0    36.0    4442000.0
# 685        1.0             1           1.0    36.0    4421000.0
# ..         ...           ...           ...     ...          ...
# 475        2.0             1           2.0   150.0     920000.0
# 469        2.0             2           3.0   157.0     840259.0
# 952        2.0             1           3.0   191.0     900000.0
# 956        2.0             1           3.0   327.0     958789.0
# 541        2.0             1           2.0  7210.0    4198000.0
#
#      price_square_meter   ZIP                Calle            Ciudad
# 162       146524.373626  6700               Tonalá  Ciudad de México
# ...
